# %% [markdown]
# ### Initial Model and Regularisation Experiment Models Validation
# #### File Set-Up

# %%
# solves occasional error with Linux commands and encoding
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# mount google drive for saving runs and model files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# copy dataset from google drive
# !unzip /content/drive/MyDrive/UniStuff/Dissertation/Dataset_zips/WSP_Full_Boxes_Only.zip -d /content/datasets/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/datasets/WSP_Full_Boxes_Only/train/labels/2782_jpg.rf.607cfbec890451d1f9fcff8516f4945d_greyscale_reversed.txt
#   inflating: /content/datasets/WSP_Full_Boxes_Only/train/labels/2782_jpg.rf.607cfbec890451d1f9fcff8516f4945d_inc_brightness.txt
#   inflating: /content/datasets/WSP_Full_Boxes_Only/train/labels/2782_jpg.rf.607cfbec890451d1f9fcff8516f4945d_inc_brightness_flipped.txt
#   inflating: /content/datasets/WSP_Full_Boxes_Only/train/labels/2782_jpg.rf.607cfbec890451d1f9fcff8516f4945d_inc_brightness_reversed.txt
#   inflating: /content/datasets/WSP_Full_Boxes_Only/train/labels/2782_jpg.rf.607cfbec890451d1f9fcff8516f4945d_inc_contrast.txt
#   inflating: /content/datasets/WSP_Full_Boxes_Only/train/labels/2782_jpg.rf.607cfbec890451d1f9fcff8516f4945d_inc_contrast_flipped.txt
#   inflating: /content/datasets/WSP_Full_Boxes_Only/train/labels/2782_jpg.rf.607cfbec890451d1f9fcff8516f4945d_inc_contrast_reversed.txt
# ...

# %%
# install and import ultralytics

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Setup complete ✅ (12 CPUs, 53.0 GB RAM, 31.1/78.2 GB disk)

# %% [markdown]
# ## Model Validation
# Validating the initial 100-epoch overfitting model, as well as the models from the regularisation experiments

# %%
# initial model trained on expanded dataset, overfitting present
model = YOLO("/content/drive/MyDrive/UniStuff/Dissertation/ModelRuns/model_boxes_only/weights/best.pt")
metrics = model.val(data="/content/datasets/WSP_Full_Boxes_Only/data.yaml")
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Model summary (fused): 268 layers, 68132235 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/datasets/WSP_Full_Boxes_Only/valid/labels.cache... 153 images, 1 backgrounds, 0 corrupt: 100%|██████████| 153/153 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/10 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:05<00:00,  1.96it/s]
#                    all        153        423       0.72      0.717      0.725      0.591
# ...

# %%
# copy files to drive
# !cp -r /content/runs/detect/val3 /content/drive/MyDrive/UniStuff/Dissertation/ModelRuns/model_boxes_only/

# %%
# increased weight decay model
model_increased_weight_decay = YOLO("/content/drive/MyDrive/UniStuff/Dissertation/ModelRuns/model_increased_weight_decay/weights/best.pt")
model_increased_weight_decay.val(data="/content/datasets/WSP_Full_Boxes_Only/data.yaml", plots=True, save_json=True)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Model summary (fused): 268 layers, 68132235 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/datasets/WSP_Full_Boxes_Only/valid/labels.cache... 153 images, 1 backgrounds, 0 corrupt: 100%|██████████| 153/153 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/10 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:07<00:00,  1.37it/s]
#                    all        153        423      0.624      0.336      0.367      0.245
# ...

# %%
# copy files to drive
# !cp -r /content/runs/detect/val4 /content/drive/MyDrive/UniStuff/Dissertation/ModelRuns/model_increased_weight_decay/

# %%
# dropout test model
model_with_dropout = YOLO("/content/drive/MyDrive/UniStuff/Dissertation/ModelRuns/model_with_dropout/weights/best.pt")
model_with_dropout.val(data="/content/datasets/WSP_Full_Boxes_Only/data.yaml", plots=True, save_json=True)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Model summary (fused): 268 layers, 68132235 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/datasets/WSP_Full_Boxes_Only/valid/labels.cache... 153 images, 1 backgrounds, 0 corrupt: 100%|██████████| 153/153 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/10 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
#                    all        153        423      0.548      0.478      0.497      0.338
# ...

# %%
# copy files to drive
# !cp -r /content/runs/detect/val5 /content/drive/MyDrive/UniStuff/Dissertation/ModelRuns/model_with_dropout/

# %%
# model with augmentations disabled
model_augment_disabled = YOLO("/content/drive/MyDrive/UniStuff/Dissertation/ModelRuns/model_augment_disabled/weights/best.pt")
model_augment_disabled.val(data="/content/datasets/WSP_Full_Boxes_Only/data.yaml", plots=True, save_json=True)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Model summary (fused): 268 layers, 68132235 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/datasets/WSP_Full_Boxes_Only/valid/labels.cache... 153 images, 1 backgrounds, 0 corrupt: 100%|██████████| 153/153 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/10 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:07<00:00,  1.39it/s]
#                    all        153        423       0.66      0.601      0.636      0.506
# ...

# %%
# copy files to drive
# !cp -r /content/runs/detect/val6 /content/drive/MyDrive/UniStuff/Dissertation/ModelRuns/model_augment_disabled/

# %%
# model augmentation increased
model_augment_increased = YOLO("/content/drive/MyDrive/UniStuff/Dissertation/ModelRuns/model_augment_increased/weights/best.pt")
model_augment_increased.val(data="/content/datasets/WSP_Full_Boxes_Only/data.yaml", plots=True, save_json=True)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Model summary (fused): 268 layers, 68132235 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/datasets/WSP_Full_Boxes_Only/valid/labels.cache... 153 images, 1 backgrounds, 0 corrupt: 100%|██████████| 153/153 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/10 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:07<00:00,  1.32it/s]
#                    all        153        423       0.73      0.593      0.631      0.442
# ...

# %%
# copy files to drive
# !cp -r /content/runs/detect/val7 /content/drive/MyDrive/UniStuff/Dissertation/ModelRuns/model_augment_increased/
